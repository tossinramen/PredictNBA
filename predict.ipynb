# %%
import pandas as pd

# %%
df = pd.read_csv("nba_games.csv", index_col=0)

# %%
df
# Out:
#           mp   mp.1    fg    fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0      240.0  240.0  36.0   88.0  0.409   8.0  32.0  0.250  19.0  25.0  ...
# 1      240.0  240.0  38.0   83.0  0.458   5.0  22.0  0.227  21.0  25.0  ...
# 2      240.0  240.0  47.0   97.0  0.485  15.0  41.0  0.366  13.0  19.0  ...
# 3      240.0  240.0  43.0   80.0  0.538  16.0  30.0  0.533  19.0  21.0  ...
# 4      240.0  240.0  38.0   76.0  0.500   7.0  21.0  0.333  25.0  30.0  ...
# ...      ...    ...   ...    ...    ...   ...   ...    ...   ...   ...  ...
# 19525  240.0  240.0  40.0   77.0  0.519   7.0  19.0  0.368  23.0  29.0  ...
# 19526  240.0  240.0  46.0   87.0  0.529  15.0  36.0  0.417  11.0  12.0  ...
# 19527  240.0  240.0  38.0   84.0  0.452  16.0  44.0  0.364   9.0  17.0  ...
# 19528  240.0  240.0  45.0  101.0  0.446  12.0  37.0  0.324  27.0  35.0  ...
# 19529  240.0  240.0  43.0   83.0  0.518  12.0  36.0  0.333  23.0  33.0  ...
#
# ...

# %%
df = df.sort_values("date")

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#           mp   mp.1    fg    fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0      240.0  240.0  36.0   88.0  0.409   8.0  32.0  0.250  19.0  25.0  ...
# 1      240.0  240.0  38.0   83.0  0.458   5.0  22.0  0.227  21.0  25.0  ...
# 2      240.0  240.0  47.0   97.0  0.485  15.0  41.0  0.366  13.0  19.0  ...
# 3      240.0  240.0  43.0   80.0  0.538  16.0  30.0  0.533  19.0  21.0  ...
# 4      240.0  240.0  42.0   97.0  0.433   6.0  22.0  0.273  30.0  38.0  ...
# ...      ...    ...   ...    ...    ...   ...   ...    ...   ...   ...  ...
# 19525  240.0  240.0  38.0   93.0  0.409  23.0  61.0  0.377  22.0  25.0  ...
# 19526  240.0  240.0  48.0   90.0  0.533   9.0  30.0  0.300  24.0  29.0  ...
# 19527  240.0  240.0  45.0  101.0  0.446  12.0  37.0  0.324  27.0  35.0  ...
# 19528  240.0  240.0  48.0  102.0  0.471  11.0  38.0  0.289  11.0  14.0  ...
# 19529  240.0  240.0  43.0   83.0  0.518  12.0  36.0  0.333  23.0  33.0  ...
#
# ...

# %%
del df["mp.1"]
del df["mp_opp.1"]
del df["index_opp"]

# %%
def add_target(team):
    team["target"] = team["won"].shift(-1)
    return team
df = df.groupby("team",group_keys=False)

# %%
df["team"]
